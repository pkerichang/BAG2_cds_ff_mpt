# %%
import sys
sys.path.append('BAG_XBase_demo/demo_scripts')
import bootcamp_demo as d
sys.version
# Out:
#   File "BAG_XBase_demo/demo_scripts/bootcamp_demo.py", line 392
#     bprj = local_dict['bprj']
#                              ^
# TabError: inconsistent use of tabs and spaces in indentation

# %%
spec_fname = 'demo_specs/demo.yaml'
top_specs = d.read_yaml(spec_fname)
bprj = d.BagProject()

# %%
d.run_flow(bprj, top_specs, 'amp_cs')
# Out:
# computing layout
# ext_w0 = 1, ext_wend=6, tot_ntr=19
# ext_w0 = 2, ext_wend=2, tot_ntr=18
# pick
# {'g': WireArray(TrackID(layer=3, track=7.5, num=8, pitch=2), 0.791, 0.946), 's': WireArray(TrackID(layer=3, track=6.5, num=9, pitch=2), 0.981, 1.136), 'd': WireArray(TrackID(layer=3, track=7.5, num=8, pitch=2), 1.168, 1.323)}
# WireArray(TrackID(layer=3, track=7.5, num=8, pitch=2), 0.791, 0.946)
# 5.5
# creating layout
# layout done
# computing AMP_CS schematics
# creating AMP_CS schematics
# running lvs
# lvs passed
# lvs log is /tools/projects/dpgrubb/bag_bootcamp/BAG2_cds_ff_mpt/BAGTMP/dbTmp_20171107_233535yyl8fix4/lvsLog_20171107_233555ihrat0em
# computing AMP_CS_tb_dc schematics
# creating AMP_CS_tb_dc schematics
# computing AMP_CS_tb_ac_tran schematics
# creating AMP_CS_tb_ac_tran schematics
# schematic done
# setting up AMP_CS_tb_dc
# running simulation
# Waiting for simulation BagSim to finish.  You may press Ctrl-C to abort.
# Simulation took 26.1 s
# ...

# %% [markdown]
# ```python
# import abc
# ```
